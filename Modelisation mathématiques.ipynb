# %% [markdown]
# Contraintes du programme :
#
# - Tous les camions entrent et sortent dans chaque ville. Le nombre de fois qu'un véhicule entre dans un sommet est égal au nombre de fois qu'il quitte ce sommet : ![image.png](attachment:85001242-4d33-4404-b56c-4686b02176c2.png)![image.png](attachment:c1b560cf-a6c6-472e-893a-253cfd825441.png)![image.png](attachment:ffa40977-0b2b-4f0d-a8ee-abeaee56c4af.png)
# - Chaque camion passe une seule fois par ville. Chaque sommet est entrée qu'une seule fois : ![image.png](attachment:dd01e0b7-b7b3-4d88-9637-5ac9f1a9d80d.png)
# - Tous les véhicules partent du même endroit. Tout les véhicules quittent l'entrepôt : ![image.png](attachment:98c55cb7-4d18-415c-b81d-7a136f32136e.png)
# - Les capacités des camions sont respectées : ![image.png](attachment:ffe8b2db-ea4c-4a3b-8a79-10eec72fd5e4.png)
# - Les camions ne peuvent pas faire des sous tours : ![image.png](attachment:88585b4d-2f13-425e-af60-535a20db6b90.png)
#
# Fonction économique : ![image.png](attachment:be8c0487-762e-443a-a7f4-295ac13e5509.png)
